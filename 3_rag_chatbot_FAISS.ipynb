# %% [markdown]
# # CSR RAG Project - Step 3: RAG Chatbot (FAISS Version)
# # This notebook builds the final RAG chatbot using Groq API and FAISS
#
# # [markdown]
# ## Setup and Imports

# %%
import os
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
from groq import Groq
from dotenv import load_dotenv

load_dotenv()
# Out:
# c:\Users\antonius marcelino\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# True

# %% [markdown]
# # [markdown]
# ## Configuration

# %%
VECTOR_DB_PATH = "faiss_index"
EMBEDDING_MODEL = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"
GROQ_MODEL = "llama-3.3-70b-versatile"
TOP_K_RESULTS = 4

# %% [markdown]
# #  [markdown]
# ## Setup Groq API Key

# %%
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

if not GROQ_API_KEY:
    print("⚠️  WARNING: GROQ_API_KEY not found!")
    print("\nPlease:")
    print("1. Get free API key from: https://console.groq.com/")
    print("2. Create a .env file with: GROQ_API_KEY=your_key_here")
    print("3. Restart this notebook")
else:
    print("✅ Groq API key loaded!")
# Out:
# ✅ Groq API key loaded!

# %% [markdown]
# # [markdown]
# ## Load Vector Database

# %%
print("Loading vector database...")

embeddings = HuggingFaceEmbeddings(
    model_name=EMBEDDING_MODEL,
    model_kwargs={'device': 'cpu'},
    encode_kwargs={'normalize_embeddings': True}
)

vectorstore = FAISS.load_local(
    VECTOR_DB_PATH, 
    embeddings,
    allow_dangerous_deserialization=True
)

print(f"✅ Vector database loaded!")
# Out:
# Loading vector database...
# C:\Users\antonius marcelino\AppData\Local\Temp\ipykernel_16120\233906929.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# ✅ Vector database loaded!

# %% [markdown]
# # [markdown]
# ## Create Custom Prompt Template

# %%
template = """You are a helpful assistant specialized in Corporate Social Responsibility (CSR) information for Indonesian FMCG companies.

Use the following context from CSR reports to answer the question. The context includes information from various companies' annual reports and sustainability reports.

Context:
{context}

Question: {question}

Instructions:
- Answer based on the provided context
- If the information is from a specific year or company, mention it
- If the context doesn't contain enough information, say so honestly
- You can answer in English or Indonesian, matching the user's question language
- Be specific and cite which company/year when relevant
- If multiple companies have similar programs, compare them

Answer:"""

PROMPT = PromptTemplate(
    template=template,
    input_variables=["context", "question"]
)

print("✅ Custom prompt template created")
# Out:
# ✅ Custom prompt template created

# %% [markdown]
# #  [markdown]
# ## Initialize Groq Client

# %%
groq_client = Groq(api_key=GROQ_API_KEY)

print(f"✅ Groq client initialized")
print(f"   Model: {GROQ_MODEL}")
# Out:
# ✅ Groq client initialized
#    Model: llama-3.3-70b-versatile

# %% [markdown]
# # [markdown]
# ## Create RAG Query Function

# %%
def query_csr_chatbot(question, top_k=TOP_K_RESULTS, verbose=True):
    """
    Query the CSR chatbot with RAG
    """
    
    if verbose:
        print("\n" + "=" * 60)
        print(f"🔍 Question: {question}")
        print("=" * 60)
    
    # Retrieve relevant chunks
    if verbose:
        print(f"\n📚 Retrieving top {top_k} relevant documents...")
    
    relevant_docs = vectorstore.similarity_search(question, k=top_k)
    
    if verbose:
        print(f"✅ Found {len(relevant_docs)} relevant chunks:\n")
        for i, doc in enumerate(relevant_docs, 1):
            print(f"   {i}. {doc.metadata['company']} {doc.metadata['year']} "
                  f"(Chunk {doc.metadata['chunk_index']+1}/{doc.metadata['total_chunks']})")
    
    # Prepare context
    context = "\n\n---\n\n".join([
        f"Source: {doc.metadata['company']} {doc.metadata['year']}\n{doc.page_content}"
        for doc in relevant_docs
    ])
    
    # Create prompt
    prompt_text = PROMPT.format(context=context, question=question)
    
    # Query Groq
    if verbose:
        print(f"\n🤖 Querying {GROQ_MODEL}...")
    
    try:
        chat_completion = groq_client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": "You are a helpful assistant specialized in Corporate Social Responsibility information for Indonesian FMCG companies."
                },
                {
                    "role": "user",
                    "content": prompt_text
                }
            ],
            model=GROQ_MODEL,
            temperature=0.3,
            max_tokens=1000
        )
        
        answer = chat_completion.choices[0].message.content
        
        response = {
            "question": question,
            "answer": answer,
            "sources": [
                {
                    "company": doc.metadata['company'],
                    "year": doc.metadata['year'],
                    "chunk_id": doc.metadata['chunk_id']
                }
                for doc in relevant_docs
            ],
            "raw_docs": relevant_docs
        }
        
        if verbose:
            print("\n" + "=" * 60)
            print("💡 ANSWER:")
            print("=" * 60)
            print(answer)
            print("\n📎 Sources:")
            for src in response['sources']:
                print(f"   - {src['company']} {src['year']}")
        
        return response
    
    except Exception as e:
        print(f"\n❌ Error: {e}")
        return None

print("✅ RAG query function ready!")
# Out:
# ✅ RAG query function ready!

# %% [markdown]
# # [markdown]
# ## Test the Chatbot

# %%
# Test Query 1
response1 = query_csr_chatbot(
    "What is Unilever's CSR program in 2022?"
)

# %%
# Test Query 2
response2 = query_csr_chatbot(
    "What are the water conservation initiatives across all companies?"
)

# %%
# Test Query 3
response3 = query_csr_chatbot(
    "Apa program tanggung jawab sosial Indofood untuk pendidikan?"
)

# %%
# Test Query 4
response4 = query_csr_chatbot(
    "Compare energy efficiency programs between Danone and Mayora"
)
# Out:
# ============================================================
# 🔍 Question: What is Unilever's CSR program in 2022?
# ============================================================
#
# 📚 Retrieving top 4 relevant documents...
# ✅ Found 4 relevant chunks:
#
#    1. Unilever 2020 (Chunk 272/331)
#    2. Unilever 2022 (Chunk 303/472)
#    3. Unilever 2021 (Chunk 10/428)
#    4. Unilever 2023 (Chunk 109/498)
#
# 🤖 Querying llama-3.3-70b-versatile...
#
# ============================================================
# 💡 ANSWER:
# ============================================================
# Berdasarkan konteks yang disediakan, program CSR Unilever pada tahun 2022 mencakup beberapa aspek, antara lain:
#
# 1. Peningkatan produktivitas dan pengelolaan sampah: Unilever membantu beberapa pengepul untuk meningkatkan produktivitas dan mendorong peningkatan laju daur ulang sampah secara keseluruhan, seperti yang dilaporkan pada tahun 2020 (Unilever 2020).
# 2. Pemasaran dan pelabelan produk: Unilever tidak memiliki insiden signifikan terkait ketidakpatuhan terhadap peraturan pemasaran dan pelabelan pada tahun 2022 (Unilever 2022). Label kemasan produk es krim Unilever Indonesia juga mencakup informasi tentang nilai gizi, petunjuk penggunaan, dan jumlah kandungan.
# 3. Promosi pilihan camilan sehat: Unilever fokus mempromosikan pilihan camilan sehat untuk anak-anak melalui produk Paddle Pop pada tahun 2022 (Unilever 2022).
#
# Namun, perlu diingat bahwa konteks yang disediakan tidak secara spesifik membahas program CSR Unilever pada tahun 2022 secara keseluruhan. Informasi yang disediakan lebih terkait dengan tahun 2020, 2021, dan 2023. Oleh karena itu, jawaban di atas hanya berdasarkan pada informasi yang tersedia dan mungkin tidak mencakup semua aspek program CSR Unilever pada tahun 2022.
#
# 📎 Sources:
#    - Unilever 2020
#    - Unilever 2022
#    - Unilever 2021
#    - Unilever 2023
#
# ============================================================
# 🔍 Question: What are the water conservation initiatives across all companies?
# ============================================================
#
# 📚 Retrieving top 4 relevant documents...
# ✅ Found 4 relevant chunks:
#
#    1. Danone 2024 (Chunk 49/176)
#    2. Unilever 2021 (Chunk 158/428)
#    3. Danone 2024 (Chunk 47/176)
#    4. Danone 2024 (Chunk 66/176)
#
# 🤖 Querying llama-3.3-70b-versatile...
#
# ============================================================
# 💡 ANSWER:
# ============================================================
# Berdasarkan konteks yang disediakan, beberapa inisiatif konservasi air yang dilakukan oleh perusahaan FMCG di Indonesia adalah:
#
# 1. **Penggunaan air kembali** (Unilever, 2021): Unilever melakukan penggunaan air kembali untuk mengurangi jejak air.
# 2. **Mengurangi kebocoran air dan menggunakan katup otomatis** (Unilever, 2021): Unilever juga melakukan upaya untuk mengurangi kebocoran air dan menggunakan katup otomatis.
# 3. **Pemanfaatan dan peningkatan kapasitas panen air hujan** (Unilever, 2021): Unilever melakukan pemanfaatan dan peningkatan kapasitas panen air hujan untuk mengurangi ketergantungan pada sumber air lain.
# 4. **Penggunaan dan pemanfaatan Reverse Osmosis** (Unilever, 2021): Unilever menggunakan teknologi Reverse Osmosis untuk mengolah air.
# 5. **Improvement pada IPAL** (Unilever, 2021): Unilever melakukan perbaikan pada sistem pengolahan air limbah (IPAL) untuk meningkatkan efisiensi penggunaan air.
# 6. **Peningkatan proses Clean in Peace (CIP)** (Unilever, 2021): Unilever melakukan peningkatan proses Clean in Peace (CIP) untuk mengurangi penggunaan air.
# 7. **Pemanenan air hujan** (Unilever, 2021): Unilever melakukan pemanenan air hujan untuk mengurangi ketergantungan pada sumber air lain.
# 8. **Pembersihan jamur secara otomatis (auto mould cleaning) di Ice Cream** (Unilever, 2021): Unilever melakukan pembersihan jamur secara otomatis di fasilitas produksi es krim untuk mengurangi penggunaan air.
# 9. **Program Konservasi** (Danone, 2024): Danone memiliki program konservasi untuk mengembalikan air ke alam.
# 10. **Program Pertanian Regeneratif** (Danone, 2024): Danone memiliki program pertanian regeneratif untuk meningkatkan efisiensi penggunaan air dalam pertanian.
# 11. **Program Water Access, Sanitation and Hygiene (WASH)** (Danone, 2024): Danone memiliki program WASH untuk meningkatkan akses air bersih dan sanitasi bagi masyarakat.
#
# Perlu diingat bahwa informasi ini hanya berdasarkan konteks yang disediakan dan mungkin tidak mencakup semua inisiatif konservasi air yang dilakukan oleh perusahaan FMCG di Indonesia.
#
# 📎 Sources:
#    - Danone 2024
#    - Unilever 2021
#    - Danone 2024
#    - Danone 2024
#
# ============================================================
# 🔍 Question: Apa program tanggung jawab sosial Indofood untuk pendidikan?
# ============================================================
#
# 📚 Retrieving top 4 relevant documents...
# ✅ Found 4 relevant chunks:
#
#    1. Indofood 2022 (Chunk 296/358)
#    2. Indofood 2023 (Chunk 372/436)
#    3. Indofood 2020 (Chunk 1/137)
#    4. Indofood 2023 (Chunk 367/436)
#
# 🤖 Querying llama-3.3-70b-versatile...
#
# ============================================================
# 💡 ANSWER:
# ============================================================
# Program tanggung jawab sosial Indofood untuk pendidikan adalah Program Edukasi yang difokuskan pada kesehatan dan kesejahteraan remaja putri, serta peningkatan kesadaran akan malnutrisi dan stunting. Menurut laporan Indofood 2022, program ini bertujuan untuk memberikan pengetahuan yang dibutuhkan bagi remaja putri untuk mengambil keputusan terkait kesehatan pribadi dan keluarga mereka. Selain itu, Indofood juga mendukung pengembangan modul khusus tentang gizi dan kesehatan, seperti yang disebutkan dalam laporan Indofood 2023, yang dirancang untuk tenaga kesehatan dan kader Posyandu.
#
# Program ini juga terkait dengan layanan kesehatan Posyandu, yang merupakan elemen utama dalam layanan kesehatan Indofood, dengan fokus pada pencegahan penyakit dan edukasi masyarakat. Menurut laporan Indofood 2023, program ini telah membantu meningkatkan kesadaran akan malnutrisi dan stunting, serta memperluas jejaring SBN (Stunting Bebas Nutrisi).
#
# Dalam laporan Indofood 2020, disebutkan bahwa Indofood berkomitmen untuk menjalankan kegiatan operasional secara berkelanjutan dan bertanggung jawab, termasuk dalam bidang pendidikan dan kesehatan. Oleh karena itu, program tanggung jawab sosial Indofood untuk pendidikan dapat disimpulkan sebagai upaya untuk meningkatkan kesehatan dan kesejahteraan masyarakat, terutama remaja putri dan ibu-ibu, melalui edukasi dan layanan kesehatan.
#
# 📎 Sources:
#    - Indofood 2022
#    - Indofood 2023
#    - Indofood 2020
#    - Indofood 2023
#
# ============================================================
# 🔍 Question: Compare energy efficiency programs between Danone and Mayora
# ============================================================
#
# 📚 Retrieving top 4 relevant documents...
# ✅ Found 4 relevant chunks:
#
#    1. Mayora 2020 (Chunk 81/115)
#    2. Danone 2024 (Chunk 34/176)
#    3. Danone 2024 (Chunk 31/176)
#    4. Mayora 2020 (Chunk 80/115)
#
# 🤖 Querying llama-3.3-70b-versatile...
#
# ============================================================
# 💡 ANSWER:
# ============================================================
# Berdasarkan konteks yang disediakan, baik Danone maupun Mayora memiliki program efisiensi energi.
#
# Pada tahun 2020, Mayora (Mayora 2020) melaporkan beberapa upaya penghematan energi, termasuk substitusi peralatan listrik dengan peralatan hemat energi, penerapan sensor motion untuk lampu, pemanfaatan ampas kopi untuk boiler, dan penggunaan solar panel untuk penerangan jalan. Mayora juga berhasil mengurangi penggunaan energi sebesar 11,5% untuk bahan bakar diesel dan 3,4% untuk gas alam, serta mengurangi emisi CO2 sebesar 5,26% per unit produk dibandingkan dengan tahun sebelumnya.
#
# Sementara itu, Danone (Danone 2024) juga melaporkan upaya efisiensi energi, termasuk pengurangan konsumsi energi listrik, CNG, diesel, dan propana/gas butana. Pada tahun 2024, Danone-AQUA mengalami penurunan konsumsi energi listrik sebesar 0,1% dan peningkatan konsumsi energi CNG sebesar 15,04%. Danone juga melakukan pengukuran intensitas energi untuk menilai efektivitas strategi efisiensi energi, yang menunjukkan bahwa nilai intensitas energi cenderung stabil dalam tiga tahun terakhir.
#
# Perbandingan antara kedua perusahaan menunjukkan bahwa Mayora (2020) memiliki target pengurangan energi yang lebih spesifik, yaitu 11,5% untuk bahan bakar diesel dan 3,4% untuk gas alam. Sementara itu, Danone (2024) memiliki data konsumsi energi yang lebih rinci, termasuk konsumsi energi listrik, CNG, diesel, dan propana/gas butana. Namun, perlu diingat bahwa data yang disediakan berasal dari tahun yang berbeda, sehingga perbandingan langsung antara kedua perusahaan mungkin tidak sepenuhnya akurat.
#
# Dalam hal program efisiensi energi, kedua perusahaan memiliki pendekatan yang serupa, yaitu mengurangi konsumsi energi dan mengoptimalkan penggunaan energi. Namun, Mayora (2020) memiliki fokus yang lebih kuat pada pengurangan emisi CO2, sementara Danone (2024) memiliki fokus yang lebih kuat pada pengukuran intensitas energi untuk menilai efektivitas strategi efisiensi energi.
#
# 📎 Sources:
#    - Mayora 2020
#    - Danone 2024
#    - Danone 2024
#    - Mayora 2020

# %% [markdown]
# #  [markdown]
# ## Interactive Chat Loop

# %%
# %%
def interactive_chat():
    """
    Interactive chat loop
    """
    print("\n" + "=" * 60)
    print("CSR CHATBOT - INTERACTIVE MODE")
    print("=" * 60)
    print("Ask questions about CSR programs of:")
    print("  - Danone, Indofood, Mayora, Ultra Jaya, Unilever")
    print("  - Years: 2019-2023")
    print("\nType 'quit' or 'exit' to stop\n")
    
    while True:
        try:
            question = input("You: ").strip()
            
            if question.lower() in ['quit', 'exit', 'q']:
                print("\n👋 Goodbye!")
                break
            
            if not question:
                continue
            
            response = query_csr_chatbot(question, verbose=True)
            
            print("\n" + "-" * 60 + "\n")
            
        except KeyboardInterrupt:
            print("\n\n👋 Goodbye!")
            break
        except Exception as e:
            print(f"\n❌ Error: {e}\n")
# Uncomment to run
# interactive_chat()

# %% [markdown]
# #  [markdown]
# ## Advanced: Filter by Metadata

# %%
def query_with_filter(question, company=None, year=None, top_k=4):
    """
    Query with manual filtering by company/year
    Note: FAISS doesn't have built-in metadata filtering,
    so we filter results after retrieval
    """
    
    print(f"\n🔍 Question: {question}")
    if company or year:
        print(f"📌 Filters: company={company}, year={year}")
    
    # Retrieve more results than needed
    relevant_docs = vectorstore.similarity_search(question, k=top_k*3)
    
    # Manual filtering
    filtered_docs = []
    for doc in relevant_docs:
        if company and doc.metadata['company'] != company:
            continue
        if year and doc.metadata['year'] != year:
            continue
        filtered_docs.append(doc)
        if len(filtered_docs) >= top_k:
            break
    
    if not filtered_docs:
        print("❌ No documents found matching the filters")
        return None
    
    print(f"✅ Found {len(filtered_docs)} relevant chunks")
    
    context = "\n\n---\n\n".join([
        f"Source: {doc.metadata['company']} {doc.metadata['year']}\n{doc.page_content}"
        for doc in filtered_docs
    ])
    
    prompt_text = PROMPT.format(context=context, question=question)
    
    chat_completion = groq_client.chat.completions.create(
        messages=[
            {"role": "system", "content": "You are a CSR information assistant."},
            {"role": "user", "content": prompt_text}
        ],
        model=GROQ_MODEL,
        temperature=0.3,
        max_tokens=1000
    )
    
    answer = chat_completion.choices[0].message.content
    
    print("\n💡 ANSWER:")
    print("=" * 60)
    print(answer)
    
    return answer

# Example
print("\n--- Filter by Unilever only ---")
query_with_filter(
    "What are the sustainability initiatives?",
    company="Unilever"
)

# %%
print("\n--- Filter by 2023 only ---")
query_with_filter(
    "What are the latest CSR programs?",
    year=2023
)
# Out:
# --- Filter by Unilever only ---
#
# 🔍 Question: What are the sustainability initiatives?
# 📌 Filters: company=Unilever, year=None
# ✅ Found 2 relevant chunks
#
# 💡 ANSWER:
# ============================================================
# Berdasarkan konteks yang disediakan, beberapa inisiatif keberlanjutan yang dapat disebutkan adalah:
#
# 1. Pengurangan sampah plastik: Unilever (2024) melalui Yayasan Rumah Pelangi, mempromosikan kesadaran akan pentingnya pengurangan sampah plastik dan melakukan pencatatan yang akurat terhadap jumlah sampah plastik yang terkumpul.
# 2. Edukasi dan pendampingan: Unilever (2024) juga menyusun strategi edukasi dan pendampingan yang lebih cermat bagi mitra pengumpul sampah.
# 3. Pendanaan untuk wastepreneur: Unilever (2024), bersama dengan USAID dan EY, berkolaborasi untuk memberikan pendanaan kepada wiraswasta dan UMKM yang bergerak di bidang limbah plastik (wastepreneur) untuk memperluas usaha mereka dalam pengurangan penggunaan kemasan plastik dan mengatasi limbah plastik.
# 4. Efisiensi energi: Unilever (2023) melanjutkan berbagai langkah inisiatif efisiensi energi, seperti memasang filter harmonik yang dapat mengurangi konsumsi listrik sebesar 2% dan mengganti refrigerant R22 dengan yang lebih ramah lingkungan di gedung Learning Centre dan Lodging house.
# 5. Penghematan air: Unilever (2023) juga memasang water irrigation system tambahan yang bertujuan untuk mengurangi kebutuhan air untuk irigasi sebesar 10%.
#
# Perlu diingat bahwa informasi ini hanya berasal dari konteks yang disediakan dan mungkin tidak mencakup semua inisiatif keberlanjutan yang dilakukan oleh Unilever atau perusahaan lainnya.
#
# --- Filter by 2023 only ---
#
# 🔍 Question: What are the latest CSR programs?
# 📌 Filters: company=None, year=2023
# ✅ Found 3 relevant chunks
#
# 💡 ANSWER:
# ============================================================
# Berdasarkan konteks yang disediakan, beberapa program CSR terbaru dari perusahaan FMCG di Indonesia adalah:
#
# 1. **Pengurangan Emisi**: Indofood (2023) telah mengimplementasikan beberapa inisiatif untuk mengurangi emisi, seperti pemanfaatan smart sensor, teknologi inverter, dan motor dengan efisiensi tinggi untuk mengurangi konsumsi listrik dan emisi Scope 2. Mereka juga menggunakan mesin forklift bertenaga baterai untuk mengurangi emisi Scope 1 dari pembakaran bahan bakar cair.
# 2. **Keselamatan dan Kesehatan Kerja**: Unilever (2023) telah mengimplementasikan program CSMS (Contractor Safety Management System) untuk meningkatkan keselamatan dan kesehatan kerja kontraktor. Mereka juga memiliki target "Vision Zero" untuk mencegah kematian dan cedera akibat kecelakaan kerja.
# 3. **Pengembangan Teknologi**: Unilever (2023) telah mengimplementasikan Cloud Computer Telephony Integration (CTI) untuk meningkatkan pengalaman konsumen melalui panggilan telepon. Teknologi ini juga membantu memantau kualitas layanan dengan lebih akurat.
#
# Perlu diingat bahwa informasi ini hanya berdasarkan konteks yang disediakan dan mungkin tidak mencakup semua program CSR yang dilakukan oleh perusahaan FMCG di Indonesia.
# 'Berdasarkan konteks yang disediakan, beberapa program CSR terbaru dari perusahaan FMCG di Indonesia adalah:\n\n1. **Pengurangan Emisi**: Indofood (2023) telah mengimplementasikan beberapa inisiatif untuk mengurangi emisi, seperti pemanfaatan smart sensor, teknologi inverter, dan motor dengan efisiensi tinggi untuk mengurangi konsumsi listrik dan emisi Scope 2. Mereka juga menggunakan mesin forklift bertenaga baterai untuk mengurangi emisi Scope 1 dari pembakaran bahan bakar cair.\n2. **Keselamatan dan Kesehatan Kerja**: Unilever (2023) telah mengimplementasikan program CSMS (Contractor Safety Management System) untuk meningkatkan keselamatan dan kesehatan kerja kontraktor. Mereka juga memiliki target "Vision Zero" untuk mencegah kematian dan cedera akibat kecelakaan kerja.\n3. **Pengembangan Teknologi**: Unilever (2023) telah mengimplementasikan Cloud Computer Telephony Integration (CTI) untuk meningkatkan pengalaman konsumen melalui panggilan telepon. Teknologi ini juga membantu memantau kualitas layanan dengan lebih akurat.\n\nPerlu diingat bahwa informasi ini hanya berdasarkan konteks yang disediakan dan mungkin tidak mencakup semua program CSR yang dilakukan oleh perusahaan FMCG di Indonesia.'

# %% [markdown]
# #  [markdown]
# ## Summary

# %%
print("\n" + "=" * 60)
print("✅ CSR RAG CHATBOT COMPLETE!")
print("=" * 60)
print("""
Your chatbot is ready! You can:

1. Use query_csr_chatbot() for queries
2. Run interactive_chat() for testing
3. Use query_with_filter() for filtered searches

Example:
  response = query_csr_chatbot("What is Danone's CSR?")
  print(response['answer'])
""")
# Out:
# ============================================================
# ✅ CSR RAG CHATBOT COMPLETE!
# ============================================================
#
# Your chatbot is ready! You can:
#
# 1. Use query_csr_chatbot() for queries
# 2. Run interactive_chat() for testing
# 3. Use query_with_filter() for filtered searches
#
# Example:
#   response = query_csr_chatbot("What is Danone's CSR?")
#   print(response['answer'])
